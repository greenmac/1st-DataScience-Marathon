# %% [markdown]
# # [作業目標]
#
#
# 1. [簡答題] 比較下列兩個讀入的 df 有什麼不同？為什麼造成的？
#
# 2. 請將 Dcard API 取得所有的看板資訊轉換成 DataFrame，並且依照熱門程度排序後存成一個 csv 的檔案。

# %% [markdown]
# # 作業

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 1. [簡答題] 比較下列兩個讀入的 df 有什麼不同？為什麼造成的？

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/dataoptimal/posts/master/data%20cleaning%20with%20python%20and%20pandas/property%20data.csv')
df1
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            1        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800

# %%
df2 = pd.read_csv(
    'https://raw.githubusercontent.com/dataoptimal/posts/master/data%20cleaning%20with%20python%20and%20pandas/property%20data.csv',
    keep_default_na=True,
    na_values=['na', '--']
)
df2
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY           12           1.0      NaN   700.0
# 4          NaN   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0

# %%
# 會預設的 NaN 值做判斷，但 na、-- 不在預設的範圍內所以沒有被轉換。

# %% [markdown]
# ### 2. 請將 Dcard API 取得所有的看板資訊轉換成 DataFrame，並且依照熱門程度排序後存成一個 csv 的檔案。

# %%
import requests
r = requests.get('https://www.dcard.tw/_api/forums')
response = r.text

import json
data = json.loads(response)

print(data)
# Out:
# x-assets.dcard.tw/images/3b2d0912-60a9-40fe-b3e2-55012df081e2/orig.jpeg', 'type': 'image/jpeg', 'width': 200, 'height': 200}, 'postCount': {'last30Days': 130}, 'favorite': False}, {'id': '79b1968a-3d30-43b9-b413-1977725cf7f0', 'alias': 'tennis', 'name': '網球', 'description': '供討論、分享、詢問與網球相關的話題。或是各種國內外賽事（例：溫網、法網等...）皆可在此討論！', 'subscriptionCount': 6182, 'subscribed': False, 'read': False, 'createdAt': '2020-02-04T07:44:03.573Z', 'updatedAt': '2021-04-20T08:36:54.364Z', 'canPost': False, 'ignorePost': False, 'invisible': False, 'isSchool': False, 'fullyAnonymous': False, 'canUseNickname': True, 'postThumbnail': {'size': 'small'}, 'shouldCategorized': True, 'shouldPostCategorized': False, 'hasPostCategories': False, 'titlePlaceholder': '發文請記得在下一步驟加入話題或其他相關分類喲！', 'postTitlePlaceholder': '', 'ipCountryCondition': {}, 'subcategories': ['溫網'], 'topics': ['溫網', '澳網', '法網', '美網', '拉沃盃'], 'nsfw': False, 'mediaThreshold': {}, 'limitCountries': [], 'limitStage': 0, 'availableLayouts': ['classic'], 'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/fc9ccbc2-2762-45d1-92fa-d52cb15b967d/orig.jpeg', 'type': 'image/jpeg', 'width': 1800, 'height': 600}, 'logo': {'url': 'https://megapx-assets.dcard.tw/images/df96afef-6c3c-493a-8bfb-f49707cdafe0/full.jpeg', 'type': 'image/jpeg', 'width': 200, 'height': 200}, 'postCount': {'last30Days': 17}, 'favorite': False}, {'id': '2ec9978e-181c-4e14-8ada-18533d1e3d45', 'alias': 'soccer', 'name': '足球', 'description': '供討論、分享、詢問與足球相關的話題。或是各種國內外賽事（例：世足賽、英超、歐冠等...）皆可在此討論！', 'subscriptionCount': 8600, 'subscribed': False, 'read': False, 'createdAt': '2020-02-04T07:44:13.573Z', 'updatedAt': '2021-04-20T08:36:58.771Z', 'canPost': False, 'ignorePost': False, 'invisible': False, 'isSchool': False, 'fullyAnonymous': False, 'canUseNickname': True, 'postThumbnail': {'size': 'small'}, 'shouldCategorized': True, 'shouldPostCategorized': False, 'hasPostCategories': False, 'titlePlaceholder': '發文請記得在下一步驟加入話題或其他相關分類喲！', 'postTitlePlaceholder': '', 'ipCountryCondition': {}, 'subcategories': [], 'topics': ['新手球迷指南', '英超', '歐冠', '球隊介紹', '轉會市場', '德甲', '西甲', '運動彩券', '法國隊', '賽事分析', 'Mbappe', '英格蘭隊', '梅西', '孫興慜', '阿根廷隊', 'C羅', '冰島', 'FIFA', '比利時隊', '西葡大戰', '世足16強賽', '內馬爾', '巴西隊', '烏龍球', '烏拉圭隊', '德國隊', '日本隊'], 'nsfw': False, 'mediaThreshold': {}, 'limitCountries': [], 'limitStage': 0, 'availableLayouts': ['classic'], 'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/ed503adf-fff4-4ca4-86a1-ed38bbea8cf8/orig.jpeg', 'type': 'image/jpeg', 'width': 1800, 'height': 600}, 'logo': {'url': 'https://megapx-assets.dcard.tw/images/bda447b4-054c-46ca-8490-5a584210b53c/full.jpeg', 'type': 'image/jpeg', 'width': 200, 'height': 200}, 'postCount': {'last30Days': 38}, 'favorite': False}, {'id': '863b960a-72a8-4479-80a2-b976275c002e', 'alias': 'basketball', 'name': '籃球', 'description': '供討論、分享、詢問與籃球相關的話題。或是各種國內外賽事（例：NBA、SBL、HBL、瓊斯盃等...）皆可在此討論！', 'subscriptionCount': 45874, 'subscribed': False, 'read': False, 'createdAt': '2020-02-04T07:44:23.573Z', 'updatedAt': '2021-04-20T08:36:38.056Z', 'canPost': False, 'ignorePost': False, 'invisible': False, 'isSchool': False, 'fullyAnonymous': False, 'canUseNickname': True, 'postThumbnail': {'size': 'small'}, 'shouldCategorized': True, 'shouldPostCategorized': False, 'hasPostCategories': False, 'titlePlaceholder': '發文請記得在下一步驟加入「相關話題」或其他相關分類喲！', 'postTitlePlaceholder': '', 'ipCountryCondition': {}, 'subcategories': [], 'topics': ['NBA', 'UBA', 'HBL', '林書豪', '瓊斯盃', 'JR', 'SBL', 'LBJ', '寶島夢想家'], 'nsfw': False, 'mediaThreshold': {}, 'limitCountries': [], 'limitStage': 0, 'availableLayouts': ['classic'], 'heroImage': {'url': 'https://megapx-assets.dcard.tw/images/992d2e61-310c-4520-aa34-54a357b5bb0b/orig.jpeg', 'type': 'image/jpeg', 'width': 1800, 'height': 600}, 'logo': {'url': 'https://megapx-assets.dcard.tw/images/a5666150-9277-4fb5-be6b-72a600c8a09e/full.jpeg', 'type': 'image/jpeg', 'width': 200, 'height': 200}, 'postCount': {'last30Days': 352}, 'favorite': False}, {'id': '4ccb34a2-4d78-4ec0-8287 ...

# %%
import pandas as pd

df =pd.DataFrame(data)
df.sort_values('subscriptionCount', ascending=False)
df.to_csv('./dcard.csv')
df
# Out:
#                                        id             alias        name  \
# 0    7f125e07-4460-4ea5-80b5-33f0e9aafa0c       midnightlab       午夜實驗室
# 1    c0ed3f99-ed1c-49a8-b413-ed5e925aafe4       timecapsule        時光膠囊
# 2    cc2164ae-88cd-466d-b11b-19e4b1f6f78c            mother         母親節
# 3    11e8d941-0aad-4960-8348-b27c36270fd1         merryxmas  聖誕CiaoCiao
# 4    8d5cabde-d0df-479f-8ab7-153209317537            father         父親節
# ..                                    ...               ...         ...
# 480  6e906a60-b8c9-401d-9183-f0bd376791b2            kebuke      可不可真心話
# 481  8e349c6d-4459-4e26-b967-430d0ebf843c     world_flipper        彈射世界
# 482  f0b871c6-ad91-41b4-8e98-0d6b3ebf2844            shinee      SHINee
# 483  0a24ebc1-46f1-4a0a-8699-bbac5ac69abd       men_dressup        男生穿搭
# 484  63e3b3ee-dc29-4aa9-80b7-def40ccf7715  epic_war_thrones        鴻圖之下
#
#                                            description  subscriptionCount  \
# 0    午夜實驗室10/6、10/7即將在華山登場！這裏提供大家交流活動資訊與討論，請大家要遵守 D...               1754
# 1    Dcard 九週年最終章！告別動盪不安的 2020，說好了，2021 我們一起活得更努力！請...               4275
# 2                                Dcard 母親節限定板，告訴媽媽我愛妳！                372
# 3             期間限定開啟！只要是和聖誕節有關的事情，或是和「禮物」有關的東西通通都來分享吧！              17374
# 4         Dcard 父親節特輯，上傳爸爸帥照，寫下真摯文字，一起謝謝我們心中的 「鋼鐵人老爸」。                371
# ..                                                 ...                ...
# 480                                                                  3008
# 481  《彈射世界》玩法以「彈珠台」為基礎，加入冒險劇情、角色培養、戰鬥系統等 RPG 元素，來享受...                 71
# 482               5늘처럼2렇게5래보자♥️\n我們就像今天一樣一起長長久久的走下去吧！💎               4143
# 483                提供男生穿搭討論的小天地，任何男性時尚潮流相關話題也可以在此發文詢問！              10405
# 484     《鴻圖之下》看板提供玩家們討論戰術攻略、情報分享、聯盟交友、玩家問答總匯等鴻圖之下相關話題。                 19
#
#      subscribed   read                 createdAt                 updatedAt  \
# 0         False  False  2016-05-14T19:15:15.698Z  2021-04-20T08:36:58.712Z
# 1         False  False  2016-05-14T20:15:15.698Z  2021-01-07T07:24:57.455Z
# 2         False  False  2016-05-14T22:15:15.699Z  2021-04-20T08:36:35.702Z
# 3         False  False  2016-05-17T00:11:15.742Z  2021-04-20T08:36:54.019Z
# 4         False  False  2016-05-17T00:12:15.742Z  2017-01-01T10:36:38.235Z
# ..          ...    ...                       ...                       ...
# 480       False  False  2021-02-17T07:25:01.859Z  2021-03-31T11:04:23.476Z
# 481       False  False  2021-02-17T08:01:18.094Z  2021-02-22T03:38:51.601Z
# 482       False  False  2021-03-08T03:44:41.998Z  2021-04-20T08:36:41.827Z
# 483       False  False  2021-04-08T07:47:31.246Z  2021-04-08T08:07:52.434Z
# 484       False  False  2021-04-13T08:58:30.139Z  2021-04-14T04:11:34.276Z
#
#      canPost  ...                                             topics   nsfw  \
# 0      False  ...                                            [午夜實驗室]  False
# 1      False  ...                                                 []  False
# 2      False  ...  [我是媽寶我驕傲, 曬媽媽, 母親節蛋糕, 康乃馨, 母親節花束, 我愛媽媽, 母親節禮物,...  False
# 3      False  ...      [Dcard聖誕列車, 交換禮物, 聖誕禮物, 聖誕卡片, 聖誕舞會, 聖誕樹, 聖誕節]  False
# 4      False  ...                                                 []  False
# ..       ...  ...                                                ...    ...
# 480    False  ...                                                 []  False
# 481    False  ...                                                 []  False
# 482    False  ...                      [SHINee, 溫流, 鐘鉉, KEY, 珉豪, 泰民]  False
# 483    False  ...                                                 []  False
# 484    False  ...                                                 []  False
#
#      mediaThreshold  limitCountries  limitStage  \
# 0                {}              []           0
# 1                {}              []           0
# 2                {}              []           0
# 3                {}              []           0
# 4                {}              []           0
# ..              ...             ...         ...
# 480              {}              []           0
# 481              {}              []           0
# 482              {}              []           0
# 483              {}              []           0
# 484              {}              []           0
#
#                   availableLayouts             postCount  favorite  \
# 0                        [classic]     {'last30Days': 1}     False
# 1                        [classic]   {'last30Days': 300}     False
# 2                        [classic]     {'last30Days': 0}     False
# 3                        [classic]     {'last30Days': 1}     False
# 4                        [classic]     {'last30Days': 0}     False
# ..                             ...                   ...       ...
# 480                      [classic]  {'last30Days': 8245}     False
# 481  [classic, image, video, link]     {'last30Days': 2}     False
# 482  [classic, image, video, link]    {'last30Days': 56}     False
# 483  [classic, video, image, link]   {'last30Days': 117}     False
# 484  [classic, video, image, link]    {'last30Days': 17}     False
#
#                                              heroImage  \
# 0                                                  NaN
# 1    {'url': 'https://megapx-assets.dcard.tw/images...
# 2                                                  NaN
# 3    {'url': 'https://megapx-assets.dcard.tw/images...
# 4                                                  NaN
# ..                                                 ...
# 480  {'url': 'https://megapx-assets.dcard.tw/images...
# 481  {'url': 'https://megapx-assets.dcard.tw/images...
# 482  {'url': 'https://megapx-assets.dcard.tw/images...
# 483  {'url': 'https://megapx-assets.dcard.tw/images...
# 484  {'url': 'https://megapx-assets.dcard.tw/images...
#
#                                                   logo
# 0                                                  NaN
# 1    {'url': 'https://megapx-assets.dcard.tw/images...
# 2                                                  NaN
# 3    {'url': 'https://megapx-assets.dcard.tw/images...
# 4                                                  NaN
# ..                                                 ...
# 480  {'url': 'https://megapx-assets.dcard.tw/images...
# 481  {'url': 'https://megapx-assets.dcard.tw/images...
# 482  {'url': 'https://megapx-assets.dcard.tw/images...
# 483  {'url': 'https://megapx-assets.dcard.tw/images...
# 484  {'url': 'https://megapx-assets.dcard.tw/images...
#
# [485 rows x 33 columns]
